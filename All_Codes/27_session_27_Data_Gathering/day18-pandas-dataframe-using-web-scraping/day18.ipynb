# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# # if response code is 403
#  - headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
#  -requests.get('url',headers=headers).text

# %%
# webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

webpage=requests.get('https://new.bollyflix.gd/page/2/').text

# %%
soup=BeautifulSoup(webpage,'lxml')
webpage
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->\n\t<!--[if IE ]>\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<![endif]-->\n\t<link rel="profile" href="https://gmpg.org/xfn/11" />\n\t\n                    <link rel="icon" href="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico" type="image/x-icon" />\n        \n                    <!-- IE10 Tile.-->\n            <meta name="msapplication-TileColor" content="#FFFFFF">\n            <meta name="msapplication-TileImage" content="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico">\n        \n                    <!--iOS/android/handheld specific -->\n            <link rel="apple-touch-icon-precomposed" href="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico" />\n        \n                    <meta name="viewport" content="width=device-width, initial-scale=1">\n            <meta name="apple-mobile-web-app-capable" content="yes">\n            <meta name="apple-mobile-web-app-status-bar-style" content="black">\n        \n        \t<link rel="pingback" href="https://new.bollyflix.gd/xmlrpc.php" />\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<script type="text/javascript">document.documentElement.className = document.documentElement.className.replace( /\\bno-js\\b/,\'js\' );</script>\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v27.5 (Yoast SEO v27.5) - https://yoast.com/product/yoast-seo-premium-wordpress/ -->\n\t<title>BollyFlix | Official Site, Bolly Flix, 300MB Movies, 9xMovies, BollyFlix.Net, BollyFlix.com</title>\n\t<meta name="description" content="Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies." />\n\t<link rel="canonical" href="https://new.bollyflix.gd/page/2/" />\n\t<link rel="prev" href="https://new.bollyflix.gd/" />\n\t<link rel="next" href="https://new.bollyflix.gd/page/3/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="website" />\n\t<meta property="og:title" content="BollyFlix" />\n\t<meta property="og:description" content="Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies." />\n\t<meta property="og:url" content="https://new.bollyflix.gd/" />\n\t<meta property="og:site_name" content="BollyFlix" />\n\t<meta property="og:image" content="https://bollyflixcdn.site/wp-content/uploads/2023/05/BollyFlix-Movies.jpg" />\n\t<meta property="og:image:width" content="1658" />\n\t<meta property="og:image:height" content="887" />\n\t<meta property="og:image:type" content="image/jpeg" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https:\\/\\/schema.org","@graph":[{"@type":"CollectionPage","@id":"https:\\/\\/new.bollyflix.gd\\/","url":"https:\\/\\/new.bollyflix.gd\\/page\\/2\\/","name":"BollyFlix | Official Site, Bolly Flix, 300MB Movies, 9xMovies, BollyFlix.Net, BollyFlix.com","isPartOf":{"@id":"https:\\/\\/new.bollyflix.gd\\/#website"},"about":{"@id":"https:\\/\\/new.bollyflix.gd\\/#organization"},"description":"Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies.","breadcrumb":{"@id":"https:\\/\\/new.bollyflix.gd\\/page\\/2\\/#breadcrumb"},"inLanguage":"en-US"},{"@type":"BreadcrumbList","@id":"https:\\/\\/new.bollyflix.gd\\/page\\/2\\/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"HOME"}]},{"@type":"WebSite","@id":"https:\\/\\/new.bollyflix.gd\\/#website","url":"https:\\/\\/new.bollyflix.gd\\/","name":"Boll ...

# %%
#print(soup.prettify())
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
# <!--[if IE ]>
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<![endif]-->
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- IE10 Tile.-->
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico" name="msapplication-TileImage"/>
# <!--iOS/android/handheld specific -->
# <link href="https://new.bollyflix.gd/wp-content/uploads/2020/02/favicon.ico" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://new.bollyflix.gd/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <script type="text/javascript">document.documentElement.className = document.documentElement.className.replace( /\bno-js\b/,'js' );</script>
# <!-- This site is optimized with the Yoast SEO Premium plugin v27.5 (Yoast SEO v27.5) - https://yoast.com/product/yoast-seo-premium-wordpress/ -->
# <title>BollyFlix | Official Site, Bolly Flix, 300MB Movies, 9xMovies, BollyFlix.Net, BollyFlix.com</title>
# <meta content="Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies." name="description"/>
# <link href="https://new.bollyflix.gd/page/2/" rel="canonical"/>
# <link href="https://new.bollyflix.gd/" rel="prev"/>
# <link href="https://new.bollyflix.gd/page/3/" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="BollyFlix" property="og:title"/>
# <meta content="Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies." property="og:description"/>
# <meta content="https://new.bollyflix.gd/" property="og:url"/>
# <meta content="BollyFlix" property="og:site_name"/>
# <meta content="https://bollyflixcdn.site/wp-content/uploads/2023/05/BollyFlix-Movies.jpg" property="og:image"/>
# <meta content="1658" property="og:image:width"/>
# <meta content="887" property="og:image:height"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https:\/\/schema.org","@graph":[{"@type":"CollectionPage","@id":"https:\/\/new.bollyflix.gd\/","url":"https:\/\/new.bollyflix.gd\/page\/2\/","name":"BollyFlix | Official Site, Bolly Flix, 300MB Movies, 9xMovies, BollyFlix.Net, BollyFlix.com","isPartOf":{"@id":"https:\/\/new.bollyflix.gd\/#website"},"about":{"@id":"https:\/\/new.bollyflix.gd\/#organization"},"description":"Download Latest Bollywood, Hollywood, Dual Audio Hindi Dubbed, 300MB Movies Movies || Google Drive Direct Download Links || BollyFlix, bollyflix, 720p BluRay Movies.","breadcrumb":{"@id":"https:\/\/new.bollyflix.gd\/page\/2\/#breadcrumb"},"inLanguage":"en-US"},{"@type":"BreadcrumbList","@id":"https:\/\/new.bollyflix.gd\/page\/2\/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"HOME"}]},{"@type":"WebSite","@id":"https:\/\/new.bollyflix.gd\/#website","url":"https:\/\/new.bollyflix.gd\/","name":"BollyFlix","description":"Official Site, Bolly Flix, 300MB Movies, 9xMovies, BollyFlix.Net, BollyFlix.com","publisher":{"@id":"https:\/\/new.bollyflix.gd\/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https:\/\/new.bollyflix.gd\/?s={search_term_string}"},"query-input":{"@type":"PropertyValueSpecification","valueRequired":true,"valueName":"search_term_string"}}],"inLanguage":"en-US"},{"@type":"Organization","@id":"https:\/\/new.bollyflix.gd\/#organization","name":"BollyFlix","url":"https:\/\/new.bollyflix.gd\/","logo":{"@type":"ImageObject","inLanguage":"en-US","@id":"https:\/\/new.bollyflix.gd\/#\/schema\/logo\/image\/","url":"https:\/\/new.bollyflix.gd\/wp-content\/uploads\/2021\/08\/Home-Banner.jpg","contentUrl":"https:\/\/new.bollyflix.gd\/wp-content\/uploads\/2021\/08\/Home-Banner.jpg","width":1246,"height":743,"caption":"BollyFlix"},"image":{"@id":"https:\/\/new.bollyflix.gd\/#\/schema\/logo\/image\/"}}]}</script>
# <!-- / Yoast SEO Premium plugin. -->
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="https://new.bollyflix.gd/feed/" rel="alternate" title="BollyFlix » Feed" type="application/rss+xml"/>
# <link href="https://new.bollyflix.gd/comments/feed/" rel="alternate" title="BollyFlix » Comments Feed" type="application/rss+xml"/>
# <link data-optimized="2" href="https://new.bollyflix.gd/wp-content/litespeed/css/b5877195339650d0a4956403ae83c03a.css?ver=84506" rel="stylesheet"/>
# <script id="utils-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var userSettings = {"url":"/","uid":"0","time":"1778525206","secure":"1"};
# //# sourceURL=utils-js-extra
# /* ]]> */
# </script>
# <script id="utils-js" src="https://new.bollyflix.gd/wp-includes/js/utils.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="jquery-core-js" src="https://new.bollyflix.gd/wp-includes/js/jquery/jquery.min.js?ver=3.7.1" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://new.bollyflix.gd/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.1" type="text/javascript"></script>
# <script id="mts_ajax-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var mts_ajax_search = {"url":"https://new.bollyflix.gd/wp-admin/admin-ajax.php","ajax_search":"1"};
# //# sourceURL=mts_ajax-js-extra
# /* ]]> */
# </script>
# <script id="mts_ajax-js" src="https://bollyflixcdn.site/wp-content/themes/mts_sociallyviral/js/ajax.js?ver=6.9.4" type="text/javascript"></script>
# <link href="https://new.bollyflix.gd/wp-json/" rel="https://api.w.org/"/><link href="https://new.bollyflix.gd/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="WordPress 6.9.4" name="generator"/>
# <title>Bollyflix</title>
# <meta content="BollyFlix,BollyFlix.co.in,BollyFlix.Net,Bollyflix.cc,Bollyflix.vip,Bollyflix.in" name="keywords"/>
# <link href="https://fonts.googleapis.com/" rel="dns-prefetch"/>
# <link href="https://blogger.googleusercontent.com/" rel="dns-prefetch"/>
# <!-- Script -->
# <!-- <script src="https://bollyflixcdn.lol/wp-content/skins/checker.js?v=1.0" defer></script> -->
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# </head>
# <body class="home blog paged wp-embed-responsive paged-2 wp-theme-mts_sociallyviral wp-child-theme-mts_sociallyviral-child main" id="blog">
# <div class="main-container">
# <header id="site-header" itemscope="" itemtype="http://schema.org/WPHeader" role="banner">
# <div class="container">
# <div id="header">
# <div class="logo-wrap">
# <h1 class="image-logo" id="logo" itemprop="headline">
# <a data-wpel-link="internal" href="https://new.bollyflix.gd"><img alt="BollyFlix" src="https://bollyflixcdn.site/wp-content/uploads/2023/05/Bollyflix-movies.png"/></a>
# </h1><!-- END #logo -->
# </div>
# <div class="header-search"><form _lpchecked="1" action="https://new.bollyflix.gd" class="search-form" id="searchform" method="get">
# <fieldset>
# <input autocomplete="off" id="s" name="s" placeholder="What are you looking for?" type="search" value=""/>
# <button class="sbutton" id="search-image" type="submit" value="">
# <i class="fa fa-search"></i>
# </button>
# </fieldset>
# </form>
# </div>
# <!-- <div class="header-social">
# <a href="https://altmovies.life/" style="background: #D35151" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"><span class="fa">New Bollywood Content</span></a>
# 					    </div> -->
# <div class="primary-navigation" id="primary-navigation" itemscope="" itemtype="http://schema.org/SiteNavigationElement" role="navigation">
# <a class="toggle-mobile-menu" href="#" id="pull">Menu</a>
# <nav class="navigation clearfix mobile-menu-wrapper">
# <ul class="menu clearfix" id="menu-top-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-94" id="menu-item-94"><a data-wpel-link="internal" href="/">🏠 HOME</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-124" id="menu-item-124"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/">🎬 MOVIES</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-144" id="menu-item-144"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/south-hindi-dubbed/">SOUTH HINDI DUBBED</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-125" id="menu-item-125"><a data-wpel-link="internal" href="https://new.bollyflix.gd/adult-movies/">ADULT MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-127" id="menu-item-127"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/bollywood/">BOLLYWOOD</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-128" id="menu-item-128"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/dual-audio-movies/">DUAL AUDIO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-129" id="menu-item-129"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/hindi-dubbed-movies-480p-720p/">HINDI DUBBED</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-130" id="menu-item-130"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/hollywood/">HOLLYWOOD</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-131" id="menu-item-131"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/multi-audio/">MULTI AUDIO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-132" id="menu-item-132"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/punjabi/">PUNJABI</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-126" id="menu-item-126"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies/bengali/">BENGALI</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-111" id="menu-item-111"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/">🔗 GENRE</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-112" id="menu-item-112"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/action/">ACTION</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-113" id="menu-item-113"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/adventure/">ADVENTURE</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-115026" id="menu-item-115026"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/animation/">ANIMATION</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-114" id="menu-item-114"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/comedy/">COMEDY</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-115" id="menu-item-115"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/crime/">CRIME</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-116" id="menu-item-116"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/drama/">DRAMA</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-117" id="menu-item-117"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/fantasy/">FANTASY</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-118" id="menu-item-118"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/historical/">HISTORICAL</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-119" id="menu-item-119"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/horror/">HORROR</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-120" id="menu-item-120"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/mystery/">MYSTERY</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-121" id="menu-item-121"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/political/">POLITICAL</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-122" id="menu-item-122"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/romance/">ROMANCE</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-46364" id="menu-item-46364"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/sci-fi/">SCI-FI</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-123" id="menu-item-123"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-genre/thriller/">THRILLER</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-133" id="menu-item-133"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/">📅 YEAR</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-881832" id="menu-item-881832"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2026/">2026</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-790085" id="menu-item-790085"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2025/">2025</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-664535" id="menu-item-664535"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2024/">2024</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-664534" id="menu-item-664534"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2023/">2023</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-374013" id="menu-item-374013"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2022/">2022</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-374012" id="menu-item-374012"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2021/">2021</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-664552" id="menu-item-664552"><a href="#">2016-2020</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-138" id="menu-item-138"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2016/">2016</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-139" id="menu-item-139"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2017/">2017</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-140" id="menu-item-140"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2018/">2018</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-141" id="menu-item-141"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2019/">2019</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-18240" id="menu-item-18240"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2020/">2020</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-137" id="menu-item-137"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2011-2015/">2011-2015</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-136" id="menu-item-136"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2006-2010/">2006-2010</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-135" id="menu-item-135"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/2001-2005/">2001-2005</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-134" id="menu-item-134"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-year/1880-2000/">1880-2000</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-142" id="menu-item-142"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-quality/">☠️ QUALITY</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-156" id="menu-item-156"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-quality/480p-movies/">480p MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-158" id="menu-item-158"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-quality/720p-movies/">720p MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-154" id="menu-item-154"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-quality/1080p-movies/">1080p MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-160" id="menu-item-160"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-size/300mb-movies/">300MB MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-157" id="menu-item-157"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-size/500mb-movies/">500MB MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-161" id="menu-item-161"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-size/700mb-movies/">700MB MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-159" id="menu-item-159"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-size/900mb-movies/">900MB MOVIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-155" id="menu-item-155"><a data-wpel-link="internal" href="https://new.bollyflix.gd/movies-by-size/1gb-movies/">1GB MOVIES</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-99" id="menu-item-99"><a data-wpel-link="internal" href="/tv-shows">📺 TV SHOWS</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-100" id="menu-item-100"><a data-wpel-link="internal" href="/web-series">🌐 WEB SERIES</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-5401" id="menu-item-5401"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/netflix/">NETFLIX</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-5397" id="menu-item-5397"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/amazon-prime-video/">AMAZON PRIME VIDEO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-229742" id="menu-item-229742"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/korean-drama/">KOREAN DRAMA</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-5399" id="menu-item-5399"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/hindi-dubbed-web-series/">HINDI DUBBED SERIES</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-364579" id="menu-item-364579"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/hotstar/">HOTSTAR</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-5400" id="menu-item-5400"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/hulu/">HULU</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-364580" id="menu-item-364580"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/mx-player-originals/">MX PLAYER ORIGINALS</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-364582" id="menu-item-364582"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/voot-select/">VOOT SELECT</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-364581" id="menu-item-364581"><a data-wpel-link="internal" href="https://new.bollyflix.gd/web-series/ongoing-series/">ONGOING SERIES</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-658275" id="menu-item-658275"><a data-wpel-link="internal" href="https://new.bollyflix.gd/anime/">ANIME</a></li>
# </ul> </nav>
# </div>
# </div><!-- #header-->
# </div><!--.container-->
# </header>
# <div class="home-h1" id="page">
# <!-- <center> <a href="https://levelbook.com/" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"><img src="https://levelbook.pages.dev/320x60/Artboard%203.jpg" /></a></center> -->
# <!--	<center> -->
# <!--	<div style="max-width:300px; align: center;">-->
# <!-- Banner -->
# <!--	<ins class="604c7625" data-key="3ec9ccc4-8368-487e-ad47-3aae6973eedb" data-cp-host="bollyflix.re"></ins>
# 	</div></center>
# -->
# <center><div>
# <a data-wpel-link="internal" href="/join" target="_blank"><button class="button buttontg"><i class="fa fa-telegram"></i> Join Telegram</button></a>
# <a data-wpel-link="internal" href="/adult-movies/"><button class="button button5"> [18+] Movies</button></a>
# <a data-wpel-link="internal" href="/movies/bollywood/"><button class="button button5">Bollywood</button></a>
# <a data-wpel-link="internal" href="/movies/hollywood/"><button class="button button5">Hollywood</button></a>
# <a data-wpel-link="internal" href="/movies/south-hindi-dubbed/"><button class="button button5">South (Hindi Dubbed)</button></a>
# <a data-wpel-link="internal" href="/movies/dual-audio-movies/"><button class="button button5">Dual Audio</button></a>
# <a data-wpel-link="internal" href="/web-series"><button class="button button5">WEB Series</button></a>
# <a data-wpel-link="internal" href="/web-series/korean-drama/"><button class="button button5">Korean Drama</button></a>
# <!-- <a href="/esearch/" data-wpel-link="internal"><button class="button button5">Search</button></a> -->
# <!-- <a href="https://altmovies.rest/" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"><button class="button button4k">ALTMovies</button></a>
# <a href="/desiflix" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"><button class="button button4k"><i class="fa fa-heart"></i> DesiFlix </button> </a> -->
# </div>
# <div class="alert"> <span class="closebtn" onclick="this.parentElement.style.display='none';">×</span> <center> <font color="WHITE" size="3px">Our New Domain is <a data-wpel-link="external" href="https://bollyflix.to/" rel="nofollow external noopener noreferrer" style="color: yellow;" target="_blank">BollyFlix.To</a> ||  Please Update Your Bookmark </font></center> </div>
# </center>
# <div id="content_box">
# <div class="post-cards">
# <article class="latestPost excerpt" id="post-907470">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/vaazha-ii-biopic-of-a-billion-bros-2026-dual-audio-hindi-malayalam-movie/" title="Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" fetchpriority="high" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Vaazha-II-Biopic-of-a-Billion-Bros-2026.jpg" title="Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/vaazha-ii-biopic-of-a-billion-bros-2026-dual-audio-hindi-malayalam-movie/">Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907410">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/love-insurance-kompany-2026-dual-audio-hindi-telugu-movie/" title="Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Love-Insurance-Kompany-2026.jpg" title="Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/love-insurance-kompany-2026-dual-audio-hindi-telugu-movie/">Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907343">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/biker-2025-dual-audio-hindi-telugu-movie/" title="Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Biker-2026-Hindi-Telugu-Movie.jpg" title="Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/biker-2025-dual-audio-hindi-telugu-movie/">Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907259">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/bhartha-mahasayulaku-wignyapthi-2026-dual-audio-hindi-telugu-movie/" title="Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Bhartha-Mahasayulaku-Wignyapthi-2026-Hindi-HQ-Dub-Telugu-Movie.jpg" title="Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/bhartha-mahasayulaku-wignyapthi-2026-dual-audio-hindi-telugu-movie/">Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-716758">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/dr-stone-season-1-multi-audio-hindi-english-japanese-anime-series/" title="Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2024/05/Dr.STONE-Anime-Series.jpg" title="Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/dr-stone-season-1-multi-audio-hindi-english-japanese-anime-series/">Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-905667">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/the-beginning-after-the-end-season-02-multi-audio-hindi-english-japanese-anime-series/" title="Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]">
# <div class="featured-thumbnail">
# <img alt="Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/04/Download-The-Beginning-After-the-End.jpg" title="Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/the-beginning-after-the-end-season-02-multi-audio-hindi-english-japanese-anime-series/">Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-903090">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/the-ramparts-of-ice-season-01-multi-audio-hindi-english-japanese-anime-series/" title="Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]">
# <div class="featured-thumbnail">
# <img alt="Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/04/Download-The-Ramparts-of-Ice.jpg" title="Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/the-ramparts-of-ice-season-01-multi-audio-hindi-english-japanese-anime-series/">Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907219">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/worst-ex-ever-dual-audio-hindi-english-web-series/" title="Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Worst-Ex-Ever-WEB-Series.jpg" title="Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/worst-ex-ever-dual-audio-hindi-english-web-series/">Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907169">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/the-chestnut-man-multi-audio-hindi-english-danish-web-series/" title="Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/The-Chestnut-Man-WEB-Series.jpg" title="Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/the-chestnut-man-multi-audio-hindi-english-danish-web-series/">Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907111">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/my-brother-the-minotaur-english-anime-series/" title="Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/My-Brother-The-Minotaur-Anime-Series.jpg" title="Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/my-brother-the-minotaur-english-anime-series/">Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-907091">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/legends-dual-audio-hindi-english-web-series/" title="Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub">
# <div class="featured-thumbnail">
# <img alt="Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Legends-WEB-Series.jpg" title="Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/legends-dual-audio-hindi-english-web-series/">Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-903085">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/grand-blue-dreaming-season-01-dual-audio-hindi-japanese-anime-series/" title="Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/04/Download-Grand-Blue-Dreaming.jpg" title="Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/grand-blue-dreaming-season-01-dual-audio-hindi-japanese-anime-series/">Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-716038">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/classroom-of-the-elite-season-1-3-multi-audio-english-japanese-anime-series/" title="Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2024/05/Classroom-of-the-Elite-Anime-Series.jpg" title="Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/classroom-of-the-elite-season-1-3-multi-audio-english-japanese-anime-series/">Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-695465">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/dorohedoro-season-1-2-multi-audio-hindi-english-japanese-anime-series/" title="Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="557" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2024/03/Dorohedoro.jpg" title="Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/dorohedoro-season-1-2-multi-audio-hindi-english-japanese-anime-series/">Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-898040">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/easygoing-territory-defense-by-the-optimistic-lord-season-01-dual-audio-hindi-japanese-anime-series/" title="Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/03/Download-Easygoing-Territory-Defense-by-the-Optimistic-Lord.jpg" title="Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/easygoing-territory-defense-by-the-optimistic-lord-season-01-dual-audio-hindi-japanese-anime-series/">Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-906629">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/eren-the-southpaw-season-01-dual-audio-hindi-japanese-anime-series/" title="Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/05/Download-Eren-the-Southpaw.jpg" title="Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/eren-the-southpaw-season-01-dual-audio-hindi-japanese-anime-series/">Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-625866">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/reborn-as-a-vending-machine-i-now-wander-the-dungeon-season-1-multi-audio-hindi-english-japanese-web-series/" title="Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2023/09/Reborn-as-a-Vending-Machine-I-Now-Wander-the-Dungeon.jpg" title="Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/reborn-as-a-vending-machine-i-now-wander-the-dungeon-season-1-multi-audio-hindi-english-japanese-web-series/">Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-898956">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/scum-of-the-brave-season-01-dual-audio-hindi-japanese-anime-series/" title="Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/03/Download-Scum-of-the-Brave.jpg" title="Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]" width="400"/> </div>
# </a>
# <header>
# <h2 class="title front-view-title"><a data-wpel-link="internal" href="https://new.bollyflix.gd/scum-of-the-brave-season-01-dual-audio-hindi-japanese-anime-series/">Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]</a></h2> </header>
# </article><article class="latestPost excerpt" id="post-905671">
# <a class="post-image post-image-left" data-wpel-link="internal" href="https://new.bollyflix.gd/witch-hat-atelier-season-01-dual-audio-hindi-japanese-anime-series/" title="Download Witch Hat Atelier (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E03 Added]">
# <div class="featured-thumbnail">
# <img alt="Download Witch Hat Atelier (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E03 Added]" class="attachment-sociallyviral-featuredbig size-sociallyviral-featuredbig wp-post-image" decoding="async" height="600" loading="eager" src="https://bollyflixcdn.site/wp-content/uploads/2026/04/Download-Witch-Hat-Atelier.jpg" title="Download Witch Hat Atelier (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E03 Added]" width="400"/> </div>
# </a>
# <header>
# ...
#             }
#         });
#     }
# });
# </script>
# <script id="editor-js" src="https://new.bollyflix.gd/wp-admin/js/editor.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="editor-js-after" type="text/javascript">
# /* <![CDATA[ */
# window.wp.oldEditor = window.wp.editor;
# //# sourceURL=editor-js-after
# /* ]]> */
# </script>
# <script id="quicktags-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var quicktagsL10n = {"closeAllOpenTags":"Close all open tags","closeTags":"close tags","enterURL":"Enter the URL","enterImageURL":"Enter the URL of the image","enterImageDescription":"Enter a description of the image","textdirection":"text direction","toggleTextdirection":"Toggle Editor Text Direction","dfw":"Distraction-free writing mode","strong":"Bold","strongClose":"Close bold tag","em":"Italic","emClose":"Close italic tag","link":"Insert link","blockquote":"Blockquote","blockquoteClose":"Close blockquote tag","del":"Deleted text (strikethrough)","delClose":"Close deleted text tag","ins":"Inserted text","insClose":"Close inserted text tag","image":"Insert image","ul":"Bulleted list","ulClose":"Close bulleted list tag","ol":"Numbered list","olClose":"Close numbered list tag","li":"List item","liClose":"Close list item tag","code":"Code","codeClose":"Close code tag","more":"Insert Read More tag"};
# //# sourceURL=quicktags-js-extra
# /* ]]> */
# </script>
# <script id="quicktags-js" src="https://new.bollyflix.gd/wp-includes/js/quicktags.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="hoverIntent-js" src="https://new.bollyflix.gd/wp-includes/js/hoverIntent.min.js?ver=1.10.2" type="text/javascript"></script>
# <script id="wp-dom-ready-js" src="https://new.bollyflix.gd/wp-includes/js/dist/dom-ready.min.js?ver=f77871ff7694fffea381" type="text/javascript"></script>
# <script id="wp-hooks-js" src="https://new.bollyflix.gd/wp-includes/js/dist/hooks.min.js?ver=dd5603f07f9220ed27f1" type="text/javascript"></script>
# <script id="wp-i18n-js" src="https://new.bollyflix.gd/wp-includes/js/dist/i18n.min.js?ver=c26c3dc7bed366793375" type="text/javascript"></script>
# <script id="wp-i18n-js-after" type="text/javascript">
# /* <![CDATA[ */
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# //# sourceURL=wp-i18n-js-after
# /* ]]> */
# </script>
# <script id="wp-a11y-js" src="https://new.bollyflix.gd/wp-includes/js/dist/a11y.min.js?ver=cb460b4676c94bd228ed" type="text/javascript"></script>
# <script id="common-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var bulkActionObserverIds = {"bulk_action":"action","changeit":"new_role"};
# //# sourceURL=common-js-extra
# /* ]]> */
# </script>
# <script id="common-js" src="https://new.bollyflix.gd/wp-admin/js/common.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="wplink-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpLinkL10n = {"title":"Insert/edit link","update":"Update","save":"Add Link","noTitle":"(no title)","noMatchesFound":"No results found.","linkSelected":"Link selected.","linkInserted":"Link inserted.","minInputLength":"3"};
# //# sourceURL=wplink-js-extra
# /* ]]> */
# </script>
# <script id="wplink-js" src="https://new.bollyflix.gd/wp-includes/js/wplink.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="jquery-ui-core-js" src="https://new.bollyflix.gd/wp-includes/js/jquery/ui/core.min.js?ver=1.13.3" type="text/javascript"></script>
# <script id="jquery-ui-menu-js" src="https://new.bollyflix.gd/wp-includes/js/jquery/ui/menu.min.js?ver=1.13.3" type="text/javascript"></script>
# <script id="jquery-ui-autocomplete-js" src="https://new.bollyflix.gd/wp-includes/js/jquery/ui/autocomplete.min.js?ver=1.13.3" type="text/javascript"></script>
# <script id="thickbox-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var thickboxL10n = {"next":"Next \u003E","prev":"\u003C Prev","image":"Image","of":"of","close":"Close","noiframes":"This feature requires inline frames. You have iframes disabled or your browser does not support them.","loadingAnimation":"https://new.bollyflix.gd/wp-includes/js/thickbox/loadingAnimation.gif"};
# //# sourceURL=thickbox-js-extra
# /* ]]> */
# </script>
# <script id="thickbox-js" src="https://new.bollyflix.gd/wp-includes/js/thickbox/thickbox.js?ver=3.1-20121105" type="text/javascript"></script>
# <script id="underscore-js" src="https://new.bollyflix.gd/wp-includes/js/underscore.min.js?ver=1.13.7" type="text/javascript"></script>
# <script id="shortcode-js" src="https://new.bollyflix.gd/wp-includes/js/shortcode.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="media-upload-js" src="https://new.bollyflix.gd/wp-admin/js/media-upload.min.js?ver=6.9.4" type="text/javascript"></script>
# <script id="customscript-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var mts_customscript = {"responsive":"1","nav_menu":"primary"};
# //# sourceURL=customscript-js-extra
# /* ]]> */
# </script>
# <script id="customscript-js" src="https://bollyflixcdn.site/wp-content/themes/mts_sociallyviral/js/customscript.js?ver=2.4.9" type="text/javascript"></script>
# <script id="shimdb_collapse_js-js" src="https://bollyflixcdn.site/wp-content/plugins/shortcode-imdb//includes/js/collapse.js?ver=6.9.4" type="text/javascript"></script>
# <script id="shimdb_scroll_js-js" src="https://bollyflixcdn.site/wp-content/plugins/shortcode-imdb//includes/js/scroll-down.js?ver=6.9.4" type="text/javascript"></script>
# <script id="shimdb_popups_js-js" src="https://bollyflixcdn.site/wp-content/plugins/shortcode-imdb//includes/js/popups.js?ver=6.9.4" type="text/javascript"></script>
# <script id="shimdb_width_js-js" src="https://bollyflixcdn.site/wp-content/plugins/shortcode-imdb//includes/js/width.js?ver=6.9.4" type="text/javascript"></script>
# <script id="wp-emoji-settings" type="application/json">
# {"baseUrl":"https://s.w.org/images/core/emoji/17.0.2/72x72/","ext":".png","svgUrl":"https://s.w.org/images/core/emoji/17.0.2/svg/","svgExt":".svg","source":{"concatemoji":"https://new.bollyflix.gd/wp-includes/js/wp-emoji-release.min.js?ver=6.9.4"}}
# </script>
# <script type="module">
# /* <![CDATA[ */
# /*! This file is auto-generated */
# const a=JSON.parse(document.getElementById("wp-emoji-settings").textContent),o=(window._wpemojiSettings=a,"wpEmojiSettingsSupports"),s=["flag","emoji"];function i(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function c(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data);e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0);const a=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data);return t.every((e,t)=>e===a[t])}function p(e,t){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var n=e.getImageData(16,16,1,1);for(let e=0;e<n.data.length;e++)if(0!==n.data[e])return!1;return!0}function u(e,t,n,a){switch(t){case"flag":return n(e,"\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!n(e,"\ud83c\udde8\ud83c\uddf6","\ud83c\udde8\u200b\ud83c\uddf6")&&!n(e,"\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!a(e,"\ud83e\u1fac8")}return!1}function f(e,t,n,a){let r;const o=(r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):document.createElement("canvas")).getContext("2d",{willReadFrequently:!0}),s=(o.textBaseline="top",o.font="600 32px Arial",{});return e.forEach(e=>{s[e]=t(o,e,n,a)}),s}function r(e){var t=document.createElement("script");t.src=e,t.defer=!0,document.head.appendChild(t)}a.supports={everything:!0,everythingExceptFlag:!0},new Promise(t=>{let n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+f.toString()+"("+[JSON.stringify(s),u.toString(),c.toString(),p.toString()].join(",")+"));",a=new Blob([e],{type:"text/javascript"});const r=new Worker(URL.createObjectURL(a),{name:"wpTestEmojiSupports"});return void(r.onmessage=e=>{i(n=e.data),r.terminate(),t(n)})}catch(e){}i(n=f(s,u,c,p))}t(n)}).then(e=>{for(const n in e)a.supports[n]=e[n],a.supports.everything=a.supports.everything&&a.supports[n],"flag"!==n&&(a.supports.everythingExceptFlag=a.supports.everythingExceptFlag&&a.supports[n]);var t;a.supports.everythingExceptFlag=a.supports.everythingExceptFlag&&!a.supports.flag,a.supports.everything||((t=a.source||{}).concatemoji?r(t.concatemoji):t.wpemoji&&t.twemoji&&(r(t.twemoji),r(t.wpemoji)))});
# //# sourceURL=https://new.bollyflix.gd/wp-includes/js/wp-emoji-loader.min.js
# /* ]]> */
# </script>
# <script type="text/javascript">
# 		window.wp = window.wp || {};
# 		window.wp.editor = window.wp.editor || {};
# 		window.wp.editor.getDefaultSettings = function() {
# 			return {
# 				tinymce: {theme:"modern",skin:"lightgray",language:"en",formats:{alignleft: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"left"}},{selector: "img,table,dl.wp-caption", classes: "alignleft"}],aligncenter: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"center"}},{selector: "img,table,dl.wp-caption", classes: "aligncenter"}],alignright: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"right"}},{selector: "img,table,dl.wp-caption", classes: "alignright"}],strikethrough: {inline: "del"}},relative_urls:false,remove_script_host:false,convert_urls:false,browser_spellcheck:true,fix_list_elements:true,entities:"38,amp,60,lt,62,gt",entity_encoding:"raw",keep_styles:false,cache_suffix:"wp-mce-49110-20250317",resize:"vertical",menubar:false,branding:false,preview_styles:"font-family font-size font-weight font-style text-decoration text-transform",end_container_on_empty_block:true,wpeditimage_html5_captions:true,wp_lang_attr:"en-US",wp_shortcut_labels:{"Heading 1":"access1","Heading 2":"access2","Heading 3":"access3","Heading 4":"access4","Heading 5":"access5","Heading 6":"access6","Paragraph":"access7","Blockquote":"accessQ","Underline":"metaU","Strikethrough":"accessD","Bold":"metaB","Italic":"metaI","Code":"accessX","Align center":"accessC","Align right":"accessR","Align left":"accessL","Justify":"accessJ","Cut":"metaX","Copy":"metaC","Paste":"metaV","Select all":"metaA","Undo":"metaZ","Redo":"metaY","Bullet list":"accessU","Numbered list":"accessO","Insert\/edit image":"accessM","Insert\/edit link":"metaK","Remove link":"accessS","Toolbar Toggle":"accessZ","Insert Read More tag":"accessT","Insert Page Break tag":"accessP","Distraction-free writing mode":"accessW","Add Media":"accessM","Keyboard Shortcuts":"accessH"},content_css:"https://new.bollyflix.gd/wp-includes/css/dashicons.min.css?ver=6.9.4,https://new.bollyflix.gd/wp-includes/js/tinymce/skins/wordpress/wp-content.css?ver=6.9.4",toolbar1:"bold,italic,bullist,numlist,link",wpautop:false,indent:true,elementpath:false,plugins:"charmap,colorpicker,hr,lists,paste,tabfocus,textcolor,fullscreen,wordpress,wpautoresize,wpeditimage,wpemoji,wpgallery,wplink,wptextpattern"},
# 				quicktags: {
# 					buttons: 'strong,em,link,ul,ol,li,code'
# 				}
# 			};
# 		};
#
# 					var tinyMCEPreInit = {
# 				baseURL: "https://new.bollyflix.gd/wp-includes/js/tinymce",
# 				suffix: ".min",
# 				mceInit: {},
# 				qtInit: {},
# 				load_ext: function(url,lang){var sl=tinymce.ScriptLoader;sl.markDone(url+'/langs/'+lang+'.js');sl.markDone(url+'/langs/'+lang+'_dlg.js');}
# 			};
# 					</script>
# <script id="wp-tinymce-root-js" src="https://new.bollyflix.gd/wp-includes/js/tinymce/tinymce.min.js?ver=49110-20250317" type="text/javascript"></script>
# <script id="wp-tinymce-js" src="https://new.bollyflix.gd/wp-includes/js/tinymce/plugins/compat3x/plugin.min.js?ver=49110-20250317" type="text/javascript"></script>
# <script type="text/javascript">
# tinymce.addI18n( 'en', {"Ok":"OK","Bullet list":"Bulleted list","Insert\/Edit code sample":"Insert\/edit code sample","Url":"URL","Spellcheck":"Check Spelling","Row properties":"Table row properties","Cell properties":"Table cell properties","Cols":"Columns","Paste row before":"Paste table row before","Paste row after":"Paste table row after","Cut row":"Cut table row","Copy row":"Copy table row","Merge cells":"Merge table cells","Split cell":"Split table cell","Paste is now in plain text mode. Contents will now be pasted as plain text until you toggle this option off.":"Paste is now in plain text mode. Contents will now be pasted as plain text until you toggle this option off.\n\nIf you are looking to paste rich content from Microsoft Word, try turning this option off. The editor will clean up text pasted from Word automatically.","Rich Text Area. Press ALT-F9 for menu. Press ALT-F10 for toolbar. Press ALT-0 for help":"Rich Text Area. Press Alt-Shift-H for help.","You have unsaved changes are you sure you want to navigate away?":"The changes you made will be lost if you navigate away from this page.","Your browser doesn't support direct access to the clipboard. Please use the Ctrl+X\/C\/V keyboard shortcuts instead.":"Your browser does not support direct access to the clipboard. Please use keyboard shortcuts or your browser\u2019s edit menu instead.","Edit|button":"Edit","Code|tab":"Code"});
# tinymce.ScriptLoader.markDone( 'https://new.bollyflix.gd/wp-includes/js/tinymce/langs/en.js' );
# </script>
# <div id="wp-link-backdrop" style="display: none"></div>
# <div aria-labelledby="link-modal-title" aria-modal="true" class="wp-core-ui" id="wp-link-wrap" role="dialog" style="display: none">
# <form id="wp-link" tabindex="-1">
# <input id="_ajax_linking_nonce" name="_ajax_linking_nonce" type="hidden" value="bc2ea1a760"/> <h1 id="link-modal-title">Insert/edit link</h1>
# <button id="wp-link-close" type="button"><span class="screen-reader-text">
# 			Close		</span></button>
# <div id="link-selector">
# <div id="link-options">
# <p class="howto" id="wplink-enter-url">Enter the destination URL</p>
# <div>
# <label><span>URL</span>
# <input aria-describedby="wplink-enter-url" id="wp-link-url" type="text"/></label>
# </div>
# <div class="wp-link-text-field">
# <label><span>Link Text</span>
# <input id="wp-link-text" type="text"/></label>
# </div>
# <div class="link-target">
# <label><span></span>
# <input id="wp-link-target" type="checkbox"/> Open link in a new tab</label>
# </div>
# </div>
# <p class="howto" id="wplink-link-existing-content">Or link to existing content</p>
# <div id="search-panel">
# <div class="link-search-wrapper">
# <label>
# <span class="search-label">Search</span>
# <input aria-describedby="wplink-link-existing-content" autocomplete="off" class="link-search-field" id="wp-link-search" type="search"/>
# <span class="spinner"></span>
# </label>
# </div>
# <div class="query-results" id="search-results" tabindex="0">
# <ul></ul>
# <div class="river-waiting">
# <span class="spinner"></span>
# </div>
# </div>
# <div class="query-results" id="most-recent-results" tabindex="0">
# <div class="query-notice" id="query-notice-message">
# <em class="query-notice-default">No search term specified. Showing recent items.</em>
# <em class="query-notice-hint screen-reader-text">
# 							Search or use up and down arrow keys to select an item.						</em>
# </div>
# <ul></ul>
# <div class="river-waiting">
# <span class="spinner"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="submitbox">
# <div id="wp-link-cancel">
# <button class="button" type="button">Cancel</button>
# </div>
# <div id="wp-link-update">
# <input class="button button-primary" id="wp-link-submit" name="wp-link-submit" type="submit" value="Add Link"/>
# </div>
# </div>
# </form>
# </div>
# </body>
# </html>
# <!-- Page cached by LiteSpeed Cache 7.8.1 on 2026-05-12 00:16:46 -->

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\n'

# %% [markdown]
# # TO FIND OUT NAMES OF THE COMPANIES

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())
# Out:
# Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]
# Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]
# Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]
# Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub
# Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub
# Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub
# Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub
# Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]
# Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]
# Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]
# Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]
# Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Witch Hat Atelier (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E03 Added]
# Download Cells at Work! (Season 01) Multi Audio {Hindi-English-Japanese} WEB Series 480p | 720p | 1080p Bluray ESub
# Posts pagination

# %%
for i in soup.find_all('h2', class_="title front-view-title"):
  print(i.text.strip())
# Out:
# Download Vaazha II: Biopic of a Billion Bros (2026) Dual Audio [Hindi-Malayalam] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download LIK: Love Insurance Kompany (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Biker (2026) Dual Audio [Hindi-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Bhartha Mahasayulaku Wignyapthi (2026) Dual Audio [Hindi (HQ Dub)-Telugu] Movie 480p | 720p | 1080p | 2160p WEB-DL ESub
# Download Dr. Stone (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E30 Added]
# Download The Beginning After the End (Season 02) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S02E03 Added]
# Download The Ramparts of Ice (Season 01) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E06 Added]
# Download Worst Ex Ever (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL ESub
# Download The Chestnut Man (Season 1-2) Multi Audio [Hindi-English-Danish] WEB Series 480p | 720p | 1080p WEB-DL ESub
# Download My Brother The Minotaur (Season 1) English Anime Series 720p | 1080p WEB-DL ESub
# Download Legends (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL ESub
# Download Grand Blue Dreaming (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Classroom of the Elite (Season 1-4) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p WEB-DL MSubs [S04E09 Added]
# Download Dorohedoro (Season 1-2) Multi Audio [Hindi-English-Japanese] Anime Series 480p | 720p | 1080p BluRay ESub [S02E20 Added]
# Download Easygoing Territory Defense by the Optimistic Lord (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Eren the Southpaw (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E02 Added]
# Download Reborn As A Vending Machine I Now Wander The Dungeon (Season 1-3) Multi Audio {Hindi-English-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S03E03 Added]
# Download Scum of the Brave (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E10 Added]
# Download Witch Hat Atelier (Season 01) Dual Audio {Hindi-Japanese} Anime Series 480p | 720p | 1080p WEB-DL ESub [S01E03 Added]
# Download Cells at Work! (Season 01) Multi Audio {Hindi-English-Japanese} WEB Series 480p | 720p | 1080p Bluray ESub

# %%
for i in soup.find_all('p'):
  print(i.text.strip())
# Out:
# File not uploaded yet.
# Enter the destination URL
# Or link to existing content

# %%
#for in soup.find_all('p'):
  #print(i.text.strip())

# %% [markdown]
# ## TO FIND OUT THE RATINGS

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 0

# %% [markdown]
# ## TO FIND OUT THE NUMBER OF REVIEWS

# %%
len(soup.find_all('a' , class_='review-count'))
# Out:
# 30

# %% [markdown]
# # CONSIDERING THE WHOLE CONTAINER

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name=[]
rating=[]
reviews=[]
ctype=[]
hq=[]
how_old=[]
no_of_employee=[]

for i in company:

  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  reviews.append(i.find('a' , class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df=pd.DataFrame({'name':name,
   'rating':rating,
   'reviews':reviews,
   'company_type':ctype,
   'Head_Quarters':hq,
   'Company_Age':how_old,
   'No_of_Employee':no_of_employee,
   })

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'ICICI Bank',
#  'Cognizant',
#  'HDFC Bank',
#  'Capgemini',
#  'Tech Mahindra',
#  'HCL Technologies',
#  'L&T',
#  'Infosys',
#  'Tata Motors',
#  'IBM',
#  'Genpact',
#  'Reliance jio',
#  'Axis Bank',
#  'Wipro',
#  'Concentrix Corporation',
#  'HDB Financial Services',
#  'Vodafone',
#  'Bharti Airtel',
#  'Kotak Mahindra Bank',
#  'Amazon',
#  'Reliance',
#  'Bajaj Finserv',
#  'IndusInd Bank',
#  'Indian Army',
#  'Teleperformance',
#  'Hinduja Global Solutions',
#  'Samsung',
#  'Mahindra & Mahindra']

# %%
rating
# Out:
# ['3.9',
#  '4.0',
#  '4.1',
#  '3.9',
#  '4.0',
#  '3.4',
#  '3.6',
#  '3.7',
#  '4.2',
#  '3.9',
#  '4.1',
#  '4.1',
#  '4.0',
#  '4.0',
#  '4.0',
#  '3.8',
#  '4.0',
#  '4.0',
#  '4.2',
#  '4.2',
#  '3.8',
#  '4.1',
#  '4.2',
#  '4.1',
#  '3.6',
#  '4.7',
#  '3.7',
#  '3.8',
#  '4.2',
#  '4.2']

# %%
reviews
# Out:
# ['17.1k Reviews',
#  '15k Reviews',
#  '13.8k Reviews',
#  '12.9k Reviews',
#  '12k Reviews',
#  '10k Reviews',
#  '9.8k Reviews',
#  '9.2k Reviews',
#  '9.1k Reviews',
#  '8.7k Reviews',
#  '8.6k Reviews',
#  '8.5k Reviews',
#  '8.3k Reviews',
#  '8.3k Reviews',
#  '8.3k Reviews',
#  '7.3k Reviews',
#  '7.3k Reviews',
#  '6.2k Reviews',
#  '5.7k Reviews',
#  '5.7k Reviews',
#  '5.7k Reviews',
#  '5.6k Reviews',
#  '4.8k Reviews',
#  '4.1k Reviews',
#  '3.9k Reviews',
#  '3.9k Reviews',
#  '3.8k Reviews',
#  '3.8k Reviews',
#  '3.6k Reviews',
#  '3.6k Reviews']

# %%
ctype
# Out:
# ['Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Govt agency',
#  'Private',
#  'Public',
#  'Private',
#  'Public']

# %%
hq
# Out:
# ['Mumbai + 164 more',
#  'Dublin + 98 more',
#  'Mumbai + 743 more',
#  'Teaneck + 46 more',
#  'Mumbai + 729 more',
#  'Paris + 45 more',
#  'Pune + 160 more',
#  'Noida + 111 more',
#  'Mumbai + 337 more',
#  'Bangalore + 68 more',
#  'Pune + 344 more',
#  'New York + 73 more',
#  'New York + 31 more',
#  'Navi Mumbai + 606 more',
#  'Mumbai + 670 more',
#  'Bangalore + 123 more',
#  'Fremont + 39 more',
#  'Ahmedabad + 463 more',
#  'Berkshire + 364 more',
#  'New Delhi + 347 more',
#  'Mumbai + 361 more',
#  'Washington + 182 more',
#  'Mumbai + 216 more',
#  'Pune + 478 more',
#  'Mumbai + 365 more',
#  'New Delhi + 211 more',
#  'Paris + 45 more',
#  'Bangalore + 52 more',
#  'Seoul + 292 more',
#  'Mumbai + 268 more']

# %%
how_old
# Out:
# ['52 years old',
#  '31 years old',
#  '26 years old',
#  '26 years old',
#  '26 years old',
#  '53 years old',
#  '34 years old',
#  '14 years old',
#  '82 years old',
#  '39 years old',
#  '75 years old',
#  '109 years old',
#  '23 years old',
#  '10 years old',
#  '27 years old',
#  '75 years old',
#  '37 years old',
#  '13 years old',
#  '38 years old',
#  '25 years old',
#  '17 years old',
#  '26 years old',
#  '54 years old',
#  '13 years old',
#  '26 years old',
#  '125 years old',
#  '42 years old',
#  '20 years old',
#  '82 years old',
#  '75 years old']

# %%
no_of_employee
# Out:
# ['10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees']

# %%
df.shape
# Out:
# (30, 7)

# %% [markdown]
# # creating dataframe for all the pages

# %%
final=pd.DataFrame()
for j in range(1,1001):
  webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
  soup=BeautifulSoup(webpage,'lxml')
  company=soup.find_all('div',class_='company-content-wrapper')
  name=[]
  rating=[]
  reviews=[]
  ctype=[]
  hq=[]
  how_old=[]
  no_of_employee=[]

  for i in company:

    try:
       name.append(i.find('h2').text.strip())
    except:
       name.append(np.nan)

    try:
       rating.append(i.find('p',class_='rating').text.strip())
    except:
       rating.append(np.nan)
   
    try:
      reviews.append(i.find('a' , class_='review-count').text.strip())
    except:
      reviews.append(np.nan)

    try:

      ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    except:
      ctype.append(np.nan)
    try:

      hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    except:
      hq.append(np.nan)
    
    try:

      how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    except:
      how_old.append(np.nan)
    try:
      no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    except:
      no_of_employee.append(np.nan)
    

  df=pd.DataFrame({'name':name,
    'rating':rating,
    'reviews':reviews,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':how_old,
    'No_of_Employee':no_of_employee,
    })
  
  final=final.append(df,ignore_index=True)

# %%
df.sample(5)
# Out:
#                            name rating  ...    Company_Age    No_of_Employee
# 2               Bank of America    4.3  ...   22 years old  10000+ employees
# 22               R.R. Donnelley    4.1  ...  156 years old  10000+ employees
# 11  Mahindra Holidays & Reso...    3.9  ...   24 years old  10000+ employees
# 23  GVK Emergency Management...    3.9  ...   15 years old  10000+ employees
# 9            Itc Infotech India    3.4  ...   20 years old  10000+ employees
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (30, 7)

# %%
final.shape
# Out:
# (30000, 7)
