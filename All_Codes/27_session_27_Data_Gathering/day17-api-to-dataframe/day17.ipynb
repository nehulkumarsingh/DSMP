# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'title': 'The Shawshank Redemption',
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 50.112,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.719,
#    'vote_count': 30278},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'title': 'The Godfather',
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 39.8763,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.686,
#    'vote_count': 22857},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'title': 'The Godfather Part II',
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 26.045,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.571,
#    'vote_count': 13862},
#   {'adult': False,
#    'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'title': "Schindler's List",
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 24.7964,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.568,
#    'vote_count': 17397},
#   {'adult': False,
#    'backdrop_path': '/w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'title': '12 Angry Men',
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 20.6809,
#    'poster_path': '/zhG3vKWyDRaZYoaww1UVAi29T9h.jpg',
#    'release_date': '1957-04-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.56,
#    'vote_count': 9942},
#   {'adult': False,
#    'backdrop_path': '/dyJvKsNs2KP8qQnAXbRwDjblViy.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'title': 'Spirited Away',
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 29.0827,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.533,
#    'vote_count': 18246},
#   {'adult': False,
#    'backdrop_path': '/cfT29Im5VDvjE0RpyKOSdCKZal7.jpg',
#    'genre_ids': [28, 80, 53],
#    'id': 155,
#    'title': 'The Dark Knight',
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 34.8577,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-16',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.529,
#    'vote_count': 35650},
#   {'adult': False,
#    'backdrop_path': '/6N5d02quKqMKqvTpOdFmBDy9scY.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 14.2747,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.513,
#    'vote_count': 4581},
#   {'adult': False,
#    'backdrop_path': '/b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'title': 'The Green Mile',
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 26.2636,
#    'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#    'release_date': '1999-12-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.505,
#    'vote_count': 19186},
#   {'adult': False,
#    'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 122,
#    'title': 'The Lord of the Rings: The Return of the King',
#    'original_language': 'en',
#    'original_title': 'The Lord of the Rings: The Return of the King',
#    'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#    'popularity': 32.8614,
#    'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#    'release_date': '2003-12-17',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.497,
#    'vote_count': 26437},
#   {'adult': False,
#    'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'title': 'Parasite',
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 35.3477,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.494,
#    'vote_count': 20553},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80, 35],
#    'id': 680,
#    'title': 'Pulp Fiction',
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 34.4785,
#    'poster_path': '/vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg',
#    'release_date': '1994-09-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.484,
#    'vote_count': 30107},
#   {'adult': False,
#    'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#    'genre_ids': [16, 10749, 18],
#    'id': 372058,
#    'title': 'Your Name.',
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 23.9284,
#    'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#    'release_date': '2016-08-26',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.476,
#    'vote_count': 12481},
#   {'adult': False,
#    'backdrop_path': '/2ssWTSVklAEc98frZUQhgtGHx7s.jpg',
#    'genre_ids': [12, 18, 878],
#    'id': 157336,
#    'title': 'Interstellar',
#    'original_language': 'en',
#    'original_title': 'Interstellar',
#    'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#    'popularity': 63.0157,
#    'poster_path': '/yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg',
#    'release_date': '2014-11-05',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.471,
#    'vote_count': 39605},
#   {'adult': False,
#    'backdrop_path': '/Adrip2Jqzw56KeuV2nAxucKMNXA.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'title': 'The Good, the Bad and the Ugly',
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 21.1095,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.468,
#    'vote_count': 9595},
#   {'adult': False,
#    'backdrop_path': '/67HggiWaP9ZLv5sPYmyRV37yAJM.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 13,
#    'title': 'Forrest Gump',
#    'original_language': 'en',
#    'original_title': 'Forrest Gump',
#    'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#    'popularity': 29.6691,
#    'poster_path': '/Cw4hIUIAmSYfK9QfaUW5igp9La.jpg',
#    'release_date': '1994-06-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.464,
#    'vote_count': 29656},
#   {'adult': False,
#    'backdrop_path': '/gILte6Zd7m1YneIr6MVhh30S9pr.jpg',
#    'genre_ids': [18, 80],
#    'id': 769,
#    'title': 'GoodFellas',
#    'original_language': 'en',
#    'original_title': 'GoodFellas',
#    'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#    'popularity': 28.4974,
#    'poster_path': '/9OkCLM73MIU2CrKZbqiT8Ln1wY2.jpg',
#    'release_date': '1990-09-12',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.453,
#    'vote_count': 14276},
#   {'adult': False,
#    'backdrop_path': '/qvZ91FwMq6O47VViAr8vZNQz3WI.jpg',
#    'genre_ids': [28, 18],
#    'id': 346,
#    'title': 'Seven Samurai',
#    'original_language': 'ja',
#    'original_title': '七人の侍',
#    'overview': "A samurai answers a village's request for protection after he falls on hard times. The town needs protection from bandits, so the samurai gathers six others to help him teach the people how to defend themselves, and the villagers provide the soldiers with food.",
#    'popularity': 17.4967,
#    'poster_path': '/lOMGc8bnSwQhS4XyE1S99uH8NXf.jpg',
#    'release_date': '1954-04-26',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.4,
#    'vote_count': 4210},
#   {'adult': False,
#    'backdrop_path': '/aHaqZpOL7UyVu0nKqp3SMz0o2E1.jpg',
#    'genre_ids': [16, 18, 10752],
#    'id': 12477,
#    'title': 'Grave of the Fireflies',
#    'original_language': 'ja',
#    'original_title': '火垂るの墓',
#    'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#    'popularity': 0.0132,
#    'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#    'release_date': '1988-04-16',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.4,
#    'vote_count': 6483},
#   {'adult': False,
#    'backdrop_path': '/xyWKrni8WrYzqn7ztvI5nIY0h62.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1181678,
#    'title': '¿Quieres ser mi hijo?',
#    'original_language': 'en',
#    'original_title': '¿Quieres ser mi hijo?',
#    'overview': 'Lu, a conformist woman in her forties, learns that her 15-year partner has been having extramarital affairs. Starting from scratch, she gets involved in an unexpected relationship with a young womanizer.',
#    'popularity': 12.9728,
#    'poster_path': '/9GuvODahvuFqdhuZ16aBLR4UJoP.jpg',
#    'release_date': '2023-09-21',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.439,
#    'vote_count': 327}],
#  'total_pages': 542,
#  'total_results': 10835}

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path        genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]      278
# 1   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg         [18, 80]      238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]      240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]      424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]      389
# 5   False  /dyJvKsNs2KP8qQnAXbRwDjblViy.jpg  [16, 10751, 14]      129
# 6   False  /cfT29Im5VDvjE0RpyKOSdCKZal7.jpg     [28, 80, 53]      155
# 7   False  /6N5d02quKqMKqvTpOdFmBDy9scY.jpg  [35, 18, 10749]    19404
# 8   False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg     [14, 18, 80]      497
# 9   False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg     [12, 14, 28]      122
# 10  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg     [35, 53, 18]   496243
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg     [53, 80, 35]      680
# 12  False  /8x9iKH8kWA0zdkgNdpAew7OstYe.jpg  [16, 10749, 18]   372058
# 13  False  /2ssWTSVklAEc98frZUQhgtGHx7s.jpg    [12, 18, 878]   157336
# 14  False  /Adrip2Jqzw56KeuV2nAxucKMNXA.jpg             [37]      429
# 15  False  /67HggiWaP9ZLv5sPYmyRV37yAJM.jpg  [35, 18, 10749]       13
# 16  False  /gILte6Zd7m1YneIr6MVhh30S9pr.jpg         [18, 80]      769
# 17  False  /qvZ91FwMq6O47VViAr8vZNQz3WI.jpg         [28, 18]      346
# 18  False  /aHaqZpOL7UyVu0nKqp3SMz0o2E1.jpg  [16, 18, 10752]    12477
# 19  False  /xyWKrni8WrYzqn7ztvI5nIY0h62.jpg      [35, 10749]  1181678
#
#                                             title original_language  \
# 0                        The Shawshank Redemption                en
# 1                                   The Godfather                en
# 2                           The Godfather Part II                en
# 3                                Schindler's List                en
# 4                                    12 Angry Men                en
# 5                                   Spirited Away                ja
# 6                                 The Dark Knight                en
# 7                     Dilwale Dulhania Le Jayenge                hi
# 8                                  The Green Mile                en
# 9   The Lord of the Rings: The Return of the King                en
# 10                                       Parasite                ko
# 11                                   Pulp Fiction                en
# 12                                     Your Name.                ja
# 13                                   Interstellar                en
# 14                 The Good, the Bad and the Ugly                it
# 15                                   Forrest Gump                en
# 16                                     GoodFellas                en
# 17                                  Seven Samurai                ja
# 18                         Grave of the Fireflies                ja
# 19                          ¿Quieres ser mi hijo?                en
#
#                                    original_title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# 5                                        千と千尋の神隠し
# 6                                 The Dark Knight
# 7                    दिलवाले दुल्हनिया ले जायेंगे
# 8                                  The Green Mile
# 9   The Lord of the Rings: The Return of the King
# 10                                            기생충
# 11                                   Pulp Fiction
# 12                                          君の名は。
# 13                                   Interstellar
# 14                Il buono, il brutto, il cattivo
# 15                                   Forrest Gump
# 16                                     GoodFellas
# 17                                           七人の侍
# 18                                          火垂るの墓
# 19                          ¿Quieres ser mi hijo?
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...     50.1120
# 1   Spanning the years 1945 to 1955, a chronicle o...     39.8763
# 2   In the continuing saga of the Corleone crime f...     26.0450
# 3   The true story of how businessman Oskar Schind...     24.7964
# 4   The defense and the prosecution have rested an...     20.6809
# 5   A young girl, Chihiro, becomes trapped in a st...     29.0827
# 6   Batman raises the stakes in his war on crime. ...     34.8577
# 7   Raj is a rich, carefree, happy-go-lucky second...     14.2747
# 8   A supernatural tale set on death row in a Sout...     26.2636
# 9   As armies mass for a final battle that will de...     32.8614
# 10  All unemployed, Ki-taek's family takes peculia...     35.3477
# 11  A burger-loving hit man, his philosophical par...     34.4785
# 12  High schoolers Mitsuha and Taki are complete s...     23.9284
# 13  The adventures of a group of explorers who mak...     63.0157
# 14  While the Civil War rages on between the Union...     21.1095
# 15  A man with a low IQ has accomplished great thi...     29.6691
# 16  The true story of Henry Hill, a half-Irish, ha...     28.4974
# 17  A samurai answers a village's request for prot...     17.4967
# 18  In the final months of World War II, 14-year-o...      0.0132
# 19  Lu, a conformist woman in her forties, learns ...     12.9728
#
#                          poster_path release_date  softcore  video  \
# 0   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     False  False
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14     False  False
# 2   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     False  False
# 3   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15     False  False
# 4   /zhG3vKWyDRaZYoaww1UVAi29T9h.jpg   1957-04-10     False  False
# 5   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20     False  False
# 6   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16     False  False
# 7   /2CAL2433ZeIihfX1Hb2139CX0pW.jpg   1995-10-20     False  False
# 8   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10     False  False
# 9   /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17     False  False
# 10  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30     False  False
# 11  /vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg   1994-09-10     False  False
# 12  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26     False  False
# 13  /yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg   2014-11-05     False  False
# 14  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-23     False  False
# 15   /Cw4hIUIAmSYfK9QfaUW5igp9La.jpg   1994-06-23     False  False
# 16  /9OkCLM73MIU2CrKZbqiT8Ln1wY2.jpg   1990-09-12     False  False
# 17  /lOMGc8bnSwQhS4XyE1S99uH8NXf.jpg   1954-04-26     False  False
# 18  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-16     False  False
# 19  /9GuvODahvuFqdhuZ16aBLR4UJoP.jpg   2023-09-21     False  False
#
#     vote_average  vote_count
# 0          8.719       30278
# 1          8.686       22857
# 2          8.571       13862
# 3          8.568       17397
# 4          8.560        9942
# 5          8.533       18246
# 6          8.529       35650
# 7          8.513        4581
# 8          8.505       19186
# 9          8.497       26437
# 10         8.494       20553
# 11         8.484       30107
# 12         8.476       12481
# 13         8.471       39605
# 14         8.468        9595
# 15         8.464       29656
# 16         8.453       14276
# 17         8.400        4210
# 18         8.400        6483
# 19         8.439         327

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     50.1120
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     39.8763
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     26.0450
# 3  The true story of how businessman Oskar Schind...   1993-12-15     24.7964
# 4  The defense and the prosecution have rested an...   1957-04-10     20.6809
#
#    vote_average  vote_count
# 0         8.719       30278
# 1         8.686       22857
# 2         8.571       13862
# 3         8.568       17397
# 4         8.560        9942

# %%
temp_df.shape
# Out:
# (20, 7)

# %%
df = pd.DataFrame()
df
df_list = []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 for i in range(1,429):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4     df = pd.concat(temp_df,ignore_index=True)
#       5
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\pandas\core\reshape\concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\pandas\core\reshape\concat.py:800, in _clean_keys_and_objs(objs, keys)
#     798     objs = [objs[k] for k in keys]
#     799 elif isinstance(objs, (ABCSeries, ABCDataFrame)) or is_scalar(objs):
# --> 800     raise TypeError(
#     801         "first argument must be an iterable of pandas "
#     802         f'objects, you passed an object of type "{type(objs).__name__}"'
#     803     )
#     804 elif not isinstance(objs, abc.Sized):
#     805     objs = list(objs)
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
df_list = [] # 1. Create an empty list

for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    
    df_list.append(temp_df) # 2. Append the dataframe to the LIST

# 3. Pass the LIST to pd.concat outside the loop
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555    9566                   The Fan
# 8556    8831                   Timecop
# 8557  483202                       Eli
# 8558  140222            Love and Honor
# 8559   25239          Day of the Woman
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  When the San Francisco Giants pay center-field...   1996-08-15
# 8556  In 2004, an officer for a security agency that...   1994-09-15
# 8557  A boy named Eli with a rare autoimmune disorde...   2019-10-18
# 8558  When a young soldier in Vietnam gets dumped by...   2013-03-22
# 8559  A young, beautiful career woman rents a backwo...   1978-11-02
#
#       popularity  vote_average  vote_count
# 0        50.1120         8.719       30278
# 1        39.8763         8.686       22857
# 2        26.0450         8.571       13862
# 3        24.7964         8.568       17397
# 4        20.6809         8.560        9942
# ...          ...           ...         ...
# 8555      2.4259         6.013         856
# 8556      3.0265         6.013        1310
# 8557      2.7186         6.012        1503
# 8558      0.7795         6.011         359
# 8559      3.4206         6.000         709
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
