# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWG  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2026-04-27
# AED  https://www.exchangerate-api.com/terms  INR 2026-04-27
# AFN  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ALL  https://www.exchangerate-api.com/terms  INR 2026-04-27
# AMD  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ..                                      ...  ...        ...
# YER  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ZAR  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ZMW  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ZWG  https://www.exchangerate-api.com/terms  INR 2026-04-27
# ZWL  https://www.exchangerate-api.com/terms  INR 2026-04-27
#
#      time_last_updated   rates
# INR         1777248001  1.0000
# AED         1777248001  0.0389
# AFN         1777248001  0.6730
# ALL         1777248001  0.8660
# AMD         1777248001  3.9500
# ..                 ...     ...
# YER         1777248001  2.5300
# ZAR         1777248001  0.1760
# ZMW         1777248001  0.2000
# ZWG         1777248001  0.2670
# ZWL         1777248001  0.2670
#
# [166 rows x 7 columns]

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/11.9 MB 1.7 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.3/11.9 MB 1.8 MB/s eta 0:00:06
#      ------ --------------------------------- 1.8/11.9 MB 2.0 MB/s eta 0:00:06
#      ------- -------------------------------- 2.4/11.9 MB 2.1 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/11.9 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.7/11.9 MB 2.3 MB/s eta 0:00:04
#      --------------- ------------------------ 4.7/11.9 MB 2.6 MB/s eta 0:00:03
#      ------------------- -------------------- 5.8/11.9 MB 2.9 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.1/11.9 MB 3.2 MB/s eta 0:00:02
#      ----------------------------- ---------- 8.7/11.9 MB 3.5 MB/s eta 0:00:01
#      -------------------------------- ------- 9.7/11.9 MB 3.6 MB/s eta 0:00:01
#      -------------------------------------- - 11.3/11.9 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 3.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (pyproject.toml): started
#   Building wheel for mysql.connector (pyproject.toml): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp313-cp313-win_amd64.whl size=248051 sha256=f241e75734aa0d0605c02e8f9f45fb46df85fe1354e1a3ce499f6c435550b57c
#   Stored in directory: c:\users\nehul singh\appdata\local\pip\cache\wheels\4e\c1\23\9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9
# [notice] A new release of pip is available: 25.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
# conn = mysql.connector.connect(host='localhost',user='root',password='@nehul114911#',database='college')
conn = mysql.connector.connect(host='DESKTOP-C10U3SH',user='root',password='@nehul114911#',database='college')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\network.py:482, in MySQLTCPSocket.open_connection(self)
#     481 try:
# --> 482     addrinfos = socket.getaddrinfo(self.server_host,
#     483                                    self.server_port,
#     484                                    0, socket.SOCK_STREAM,
#     485                                    socket.SOL_TCP)
#     486     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File C:\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # conn = mysql.connector.connect(host='localhost',user='root',password='@nehul114911#',database='college')
# ----> 2 conn = mysql.connector.connect(host='DESKTOP-C10U3SH',user='root',password='@nehul114911#',database='college')
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\connection.py:206, in MySQLConnection._open_connection(self)
#     204 self._protocol = MySQLProtocol()
#     205 self._socket = self._get_connection()
# --> 206 self._socket.open_connection()
#     207 self._do_handshake()
#     208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#
# File d:\CampusX\CampusX_Venv\Lib\site-packages\mysql\connector\network.py:500, in MySQLTCPSocket.open_connection(self)
#     498         addrinfo = addrinfos[0]
#     499 except IOError as err:
# --> 500     raise errors.InterfaceError(
#     501         errno=2003, values=(self.get_address(), _strioerror(err)))
#     502 else:
#     503     (self._family, socktype, proto, _, sockaddr) = addrinfo
#
# InterfaceError: 2003: Can't connect to MySQL server on 'DESKTOP-C10U3SH:3306' (11001 getaddrinfo failed)

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
