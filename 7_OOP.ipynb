# %%
class Atm:
  # constructor
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi, how can i help you
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      # create pin
      self.create_pin()
    elif user_input == '2':
      # change pin
      pass
    elif user_input == '3':
      # check balance
      pass
    elif user_input == '4':
      # withdraw
      pass
    else:
      exit()

  def create_pin(self):
    user_pin = input('Enter your pin: ')
    self.pin = user_pin

    user_balance = int(input('Enter your balance: '))
    self.balance = user_balance

    print('Pin created successfully')

# %%
obj = Atm()
# Out:
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin: 123456
# Enter your balance: 500
# Pin created successfully

# %%
obj.balance
# Out:
# 500

# %%
obj2 = Atm()
obj2.balance
# Out:
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     2
# 0

# %%
from os import initgroups
class Atm:
  # constructor
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi, how can i help you
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      # create pin
      self.create_pin()
    elif user_input == '2':
      # change pin
      self.change_pin()
    elif user_input == '3':
      # check balance
      self.check_balance()
    elif user_input == '4':
      # withdraw
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('Enter your pin: ')
    self.pin = user_pin

    user_balance = int(input('Enter your balance: '))
    self.balance = user_balance

    print('Pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('Enter the old pin: ')
    if old_pin == self.pin:
      # Let him to change the pin
      new_pin = input('Enter new pin: ')
      self.pin = new_pin
      print('Pin change successful')
      self.menu()
    else:
      print('Nhi karne de skta re baba!')
      self.menu()

  def check_balance(self):
    user_pin = input('Enter your pin: ')
    if user_pin == self.pin:
      print('Your balance is: ', self.balance)
    else:
      print('Chal nikal yaha se')
      self.menu()

  def withdraw(self):
    user_pin = input('Enter your pin: ')
    if user_pin == self.pin:
      # Allow to withdraw
      amount = int(input('Enter the amount: '))
      if amount <= self.balance:
        self.balance -= amount
        print('Withdrawl successful')
        print('Your current balance is ', self.balance)
      else:
        print('abe gareeb')

    else:
      print('sahi pin dal gadhe!')
    self.menu()

# %%
obj1 = Atm()
# Out:
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin: 1234
# Enter your balance: 500
# Pin created successfully
#
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     3
# Enter your pin: 1234
# Your balance is:  500

# %%
obj1.check_balance()
# Out:
# Enter your pin: 1234
# Your balance is:  500

# %%
obj2 = Atm()
# Out:
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin: 8520
# Enter your balance: 100
# Pin created successfully
#
#     Hi, how can i help you
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     3
# Enter your pin: 8520
# Your balance is:  100

# %%
obj2.check_balance()
# Out:
# Enter your pin: 8520
# Your balance is:  100

# %%
obj1.check_balance()
# Out:
# Enter your pin: 1234
# Your balance is:  500

# %%
class Fraction:
  def __init__(self, x, y):
    self.num = x
    self.deno = y

# %%
fr1 = Fraction(3,4)

# %%
print(fr1)
# 3/4
# Out:
# <__main__.Fraction object at 0x7878ac9c4890>

# %%
class Fraction:
  def __init__(self, x, y):
    self.num = x
    self.deno = y

  def __str__(self):
    return 'idhar'

# %%
fr1 = Fraction(3,4)

# %%
print(fr1)
# Out:
# idhar

# %%
class Fraction:
  def __init__(self, x, y):
    self.num = x
    self.deno = y

  def __str__(self):
    # return f'{self.num}/{self.deno}'
    return '{}/{}'.format(self.num, self.deno)

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
print(fr1)
# Out:
# 3/4

# %%
print(fr2)
# Out:
# 1/2

# %%
print(fr1 +fr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-31-3697174716.py in <cell line: 0>()
# ----> 1 print(fr1 +fr2)
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %%
s1 = {1,2,3}
s2 = {4,5,6}
print(s1 + s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-32-909422124.py in <cell line: 0>()
#       1 s1 = {1,2,3}
#       2 s2 = {4,5,6}
# ----> 3 print(s1 + s2)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
class Fraction:
  def __init__(self, x, y):
    self.num = x
    self.deno = y

  def __str__(self):
    # return f'{self.num}/{self.deno}'
    return '{}/{}'.format(self.num, self.deno)

  def __add__(self, other):
    # return 'idhar'
    # 1/2 + 7/11 = ((1*11) + (2*7))/(2*11)
    new_num = self.num*other.deno + other.num*self.deno
    new_deno = self.deno*other.deno

    return '{}/{}'.format(new_num, new_deno)

  def __sub__(self, other):
    # return 'idhar'
    # 1/2 - 7/11 = ((1*11) - (2*7))/(2*11)
    new_num = self.num*other.deno - other.num*self.deno
    new_deno = self.deno*other.deno

    return '{}/{}'.format(new_num, new_deno)

  def __mul__(self, other):
    # return 'idhar'
    # 1/2 * 7/11
    new_num = self.num*other.num
    new_deno = self.deno*other.deno

    return '{}/{}'.format(new_num, new_deno)

  def __truediv__(self, other):
    # return 'idhar'
    # 1/2 / 7/11
    new_num = self.num*other.deno
    new_deno = self.deno*other.num

    return '{}/{}'.format(new_num, new_deno)

  def convert_to_decimal(self):
    return self.num/self.deno

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
print(fr1 + fr2)
print(fr1-fr2)
print(fr1*fr2)
print(fr1/fr2)
print(fr1.convert_to_decimal())
# Out:
# 10/8
# 2/8
# 3/8
# 6/4
# 0.75

# %%
# Out:
# 2/8
