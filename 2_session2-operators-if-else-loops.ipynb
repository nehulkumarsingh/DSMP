# %% [markdown]
# # Operators in Python
#
# - Arithmetic Operators
# - Relational Operators
# - Logical Operators
# - Bitwise Operators
# - Assignment Operators
# - Membership Operators

# %%
# Arithmetric Operators
print(5+6)

print(5-6)

print(5*6)

print(5/2)

print(5//2)

print(5%2)

print(5**2)
# Out:
# 11
# -1
# 30
# 2.5
# 2
# 1
# 25

# %%
# Relational Operators
print(4>5)

print(4<5)

print(4>=4)

print(4<=4)

print(4==4)

print(4!=4)
# Out:
# False
# True
# True
# True
# True
# False

# %%
# Logical Operators
print(1 and 0)

print(1 or 0)

print(not 1)
# Out:
# 0
# 1
# False

# %%
# Bitwise Operators

# bitwise and
print(2 & 3)

# bitwise or
print(2 | 3)

# bitwise xor
print(2 ^ 3)

print(~3)

print(4 >> 2)

print(5 << 2)
# Out:
# 2
# 3
# 1
# -4
# 1
# 20

# %%
# Assignment Operators

# =
# a = 2

a = 2

# a = a % 2
a %= 2

# a++ ++a

print(a)
# Out:
# 0

# %%
# Membership Operators

# in/not in

print('D' not in 'Delhi')

print(1 in [2,3,4,5,6])

print(1 in (1,2,3,4,5))

print(1 in {1,2,3,4,5})

print(2 in {1:'a',2:'b',3:'c',4:'d',5:'e'}) # only keys
print('b' in {1:'a',2:'b',3:'c',4:'d',5:'e'})
# Out:
# False
# False
# True
# True
# True
# False

# %%
# Program - Find the sum of a 3 digit number entered by the user
num = int(input('Enter 3 digit number '))
sum = 0
while num > 0:
  a = num % 10
  sum += a
  num = num // 10;
print(sum)
# Out:
# Enter 3 digit number 123
# 6

# %%
# Program - Find the sum of a 3 digit number entered by the user

number = int(input('Enter a 3 digit number'))

# 345%10 -> 5
a = number%10

number = number//10

# 34%10 -> 4
b = number % 10

number = number//10
# 3 % 10 -> 3
c = number % 10

print(a + b + c)
# Out:
# Enter a 3 digit number123
# 6

# %% [markdown]
# # If-else in Python

# %%
# login program and indentation
# email -> nitish.campusx@gmail.com
# password -> 1234

email = input('enter email')
password = input('enter password')

if email == 'nitish.campusx@gmail.com' and password == '1234':
  print('Welcome')
elif email == 'nitish.campusx@gmail.com' and password != '1234':
  # tell the user
  print('Incorrect password')
  password = input('enter password again')
  if password == '1234':
    print('Welcome,finally!')
  else:
    print('beta tumse na ho paayega!')
else:
  print('Not correct')
# Out:
# enter email2
# enter password2
# Not correct

# %%
# login program and indentation
# email -> nehulkr30582@gmail.com
# password -> 12345

email = input('Enter Email ')
password = input('Enter Password ')

if email == 'nehulkr30582@gmail.com' and password == '12345':
  print('Welcome')

elif email == 'nehulkr30582@gmail.com' and password != '12345':
  print('Incorrect Password')
  password = input('Enter Password Again')
  if password == '12345':
    print('Welcome Finally')
  else:
    print('Beta tumse na ho paayega!')

elif email != 'nehulkr30582@gmail.com' and password == '12345':
  print('Incorrect Email')
  email = input('Enter Email Again')
  if email == 'nehulkr30582@gmail.com':
    print('Welcome finally')
  else:
    print('Beta tumse na ho paayega!')

else:
  print('Incorrect Email and Password')
# Out:
# Enter Email 2
# Enter Password 2
# Incorrect Email and Password

# %%
# if-else examples
# 1. Find the min of 3 given numbers
# 2. Menu Driven Program

# %%
# min of 3 number

a = int(input('first num'))
b = int(input('second num'))
c = int(input('third num'))

if a<b and a<c:
  print('smallest is',a)
elif b<c:
  print('smallest is',b)
else:
  print('smallest is',c)
# Out:
# first num2
# second num2
# third num2
# smallest is 2

# %%
first = int(input('enter first num '))
second = int(input('enter second num '))
third = int(input('enter third num '))

if first < second and first < third:
  print('smallest is ', first)
elif second < third:
  print(f'smallest is {second}')
else:
  print(f'smallest is {third}')
# Out:
# enter first num 2
# enter second num 2
# enter third num 2
# smallest is 2

# %%
# menu driven calculator
menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance')
else:
  print('exit')
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# 2
# balance

# %%
print("""
Hi, How can I help you?
  1. Enter 1 for pin change
  2. Enter 2 for balance check
  3. Enter 3 for withdrawl
  4. Enter 4 for exit
    """)

menu = int(input('Enter your number '))
if menu ==1:
    print('pin change')
elif menu == 2:
    print('Check balance')
elif menu == 3:
    print('withdrawl successfully')
else:
    print('Exit')

# %% [markdown]
# # Modules in Python
#
# - math
# - keywords
# - random
# - datetime

# %%
# math
import math

print(math.factorial(5))
print(math.floor(9.8))
print(math.ceil(9.8))
print(round(9.8))
print(round(9.3))
print(round(9.5))
print(int(math.sqrt(196)))
# Out:
# 120
# 9
# 10
# 10
# 9
# 10
# 14

# %%
# keyword
import keyword
# print(keyword.kwlist)
count = 0
for i in keyword.kwlist:
  print(i, end = '\t\t')
  count += 1
  if count % 10 == 0:
    print()
# Out:
# False		None		True		and		as		assert		async		await		break		class
# continue		def		del		elif		else		except		finally		for		from		global
# if		import		in		is		lambda		nonlocal		not		or		pass		raise
# return		try		while		with		yield

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 76

# %%
# datetime
import datetime
print(datetime.datetime.now())
print(datetime.datetime.now().year)
# Out:
# 2025-07-04 07:55:00.129306
# 2025

# %%
help('modules')

# %% [markdown]
# # Loops in Python
#
# - Need for loops
# - While Loop
# - For Loop

# %%
# While loop example -> program to print the table
# Program -> Sum of all digits of a given number
# Program -> keep accepting numbers from users till he/she enters a 0 and then find the avg

# %%
number = int(input('enter the number'))

i = 1

while i<11:
  print(number,'*',i,'=',number * i)
  i += 1
# Out:
# enter the number5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
# while loop with else

x = 1

while x < 3:
  print(x)
  x += 1

else:
  print('limit crossed')
# Out:
# 1
# 2
# limit crossed

# %%
# Guessing game

# generate a random integer between 1 and 100
import random
jackpot = random.randint(1,100)

guess = int(input('guess karo'))
counter = 1
while guess != jackpot:
  if guess < jackpot:
    print('galat!guess higher')
  else:
    print('galat!guess lower')

  guess = int(input('guess karo'))
  counter += 1

else:
  print('correct guess')
  print('attempts',counter)

# %%
# For loop demo

for i in {1,2,3,4,5}:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in 'Delhi':
    print(i)
# Out:
# D
# e
# l
# h
# i

# %%
for i in [1,2,3,4,5]: #List
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in (1,2,3,4,5): # Tuples
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in {1,2,3,4,5}: # Sets
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in {1:'a', 2:'b', 3:'c', 4:'d', 5:'e'}: # Dictonary
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# For loop examples

# %% [markdown]
# ### Program - The current population of a town is 10000. The population of the town is increasing at the rate of 10% per year. You have to write a program to find out the population at the end of each of the last 10 years.

# %%
curr_pop = 10000

for i in range(10,0,-1):
  print(i,curr_pop)
  curr_pop = curr_pop / 1.1
# Out:
# 10 10000
# 9 9090.90909090909
# 8 8264.462809917353
# 7 7513.148009015775
# 6 6830.134553650703
# 5 6209.213230591548
# 4 5644.739300537771
# 3 5131.5811823070635
# 2 4665.07380209733
# 1 4240.976183724845

# %% [markdown]
# ### Sequence sum
#
# 1/1! + 2/2! + 3/3! + ...

# %%
import math

n = int(input('Enter n: '))
sum = 0

for i in range(1, n+1):
    sum += i / math.factorial(i)

print(sum)
# Out:
# Enter n: 5
# 2.708333333333333

# %%
n = int(input('Enter n: '))
sum = 0
fact = 1
for i in range(1, n+1):
    fact = fact * i
    sum += i / fact

print(sum)
# Out:
# Enter n: 2
# 2.0

# %%
# For loop vs While loops (When to use what?)

# %% [markdown]
# # Nested Loops

# %%
# Examples

# %%
# Program - Unique combination of 1,2,3,4
# Program - Pattern 1 and 2

# %% [markdown]
# ### Pattern 1
#
#
# *** <br>
# **** <br>
# ***<br>

# %%
n = int(input('Enter number: '))
for i in range(1, n+1):
    for j in range(1, i+1):
        print('*', end='')
    print()
# Out:
# Enter number: 4
# *
# **
# ***
# ****

# %% [markdown]
# ### Pattern 2
#
# 1<br>
# 121<br>
# 12321<br>
# 1234321<br>

# %%
n = int(input('Enter the number: '))

for i in range(1, n+1):

    for j in range(1, i):
        print(j, end='')

    for k in range(i, 0, -1):
        print(k, end='')
    print()
# Out:
# Enter the number: 5
# 1
# 121
# 12321
# 1234321
# 123454321

# %% [markdown]
# # Loop Control Statement
#
# - Break
# - Continue
# - Pass

# %%
# Break demo

# %%
# Break example (Linear Search) -> Prime number in a given range

# %%
# Continue demo

# %%
# Continue Example (Ecommerce)

# %%
# Pass demo
